# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from tabulate import tabulate
df=pd.read_excel(r"C:\Users\SuryaKrishna\Desktop\HR LAB-5th SEM\HRlab.xlsx",sheet_name="Ex19",header=1)
df.head(5)
# Out:
#    Q1  Q2  Q3  Q4  Q1.1  Q2.1  Q1.2  Q2.2  Q3.1  Q4.1  Q1.3  Q2.3  Q3.2  Q1.4  \
# 0   3   2   3   5     4     2     1     4     3     2     3     4     1     3
# 1   5   1   2   5     2     3     1     5     2     1     1     2     2     5
# 2   1   4   1   4     3     4     2     3     4     3     5     5     5     1
# 3   3   2   3   2     1     3     1     3     4     5     3     4     1     3
# 4   4   2   5   1     1     1     1     4     3     1     2     2     2     4
#
#    Q2.4  Q3.3  Average
# 0     5     2   2.9375
# 1     1     1   2.4375
# 2     1     5   3.1875
# 3     3     2   2.6875
# 4     4     3   2.5000

# %%
print(df.describe())
print(df.dtypes)
# Out:
#               Q1         Q2         Q3         Q4       Q1.1       Q2.1  \
# count  33.000000  33.000000  33.000000  33.000000  33.000000  33.000000
# mean    3.212121   3.000000   3.363636   2.484848   2.545455   3.363636
# std     1.473889   1.391941   1.410190   1.325736   1.227062   1.387853
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     2.000000   2.000000   2.000000   1.000000   2.000000   2.000000
# 50%     3.000000   3.000000   3.000000   2.000000   2.000000   4.000000
# 75%     4.000000   4.000000   5.000000   3.000000   3.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#             Q1.2       Q2.2       Q3.1       Q4.1       Q1.3       Q2.3  \
# count  33.000000  33.000000  33.000000  33.000000  33.000000  33.000000
# mean    2.696970   2.969697   3.242424   3.030303   3.121212   3.242424
# std     1.530622   1.310650   1.299767   1.510067   1.576340   1.500631
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     1.000000   2.000000   3.000000   2.000000   1.000000   2.000000
# 50%     2.000000   3.000000   3.000000   3.000000   4.000000   3.000000
# 75%     4.000000   4.000000   4.000000   4.000000   4.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#             Q3.2       Q1.4       Q2.4       Q3.3    Average
# count  33.000000  33.000000  33.000000  33.000000  33.000000
# mean    2.818182   3.060606   3.242424   2.757576   3.009470
# std     1.445998   1.248484   1.346994   1.323591   0.406587
# min     1.000000   1.000000   1.000000   1.000000   2.375000
# 25%     2.000000   2.000000   2.000000   2.000000   2.687500
# 50%     2.000000   3.000000   3.000000   2.000000   2.937500
# 75%     4.000000   4.000000   4.000000   3.000000   3.375000
# max     5.000000   5.000000   5.000000   5.000000   3.750000
# Q1           int64
# Q2           int64
# Q3           int64
# Q4           int64
# Q1.1         int64
# Q2.1         int64
# Q1.2         int64
# Q2.2         int64
# Q3.1         int64
# Q4.1         int64
# Q1.3         int64
# Q2.3         int64
# Q3.2         int64
# Q1.4         int64
# Q2.4         int64
# Q3.3         int64
# Average    float64
# dtype: object

# %%
df.isnull().sum()
df
# Out:
#     Q1  Q2  Q3  Q4  Q1.1  Q2.1  Q1.2  Q2.2  Q3.1  Q4.1  Q1.3  Q2.3  Q3.2  \
# 0    3   2   3   5     4     2     1     4     3     2     3     4     1
# 1    5   1   2   5     2     3     1     5     2     1     1     2     2
# 2    1   4   1   4     3     4     2     3     4     3     5     5     5
# 3    3   2   3   2     1     3     1     3     4     5     3     4     1
# 4    4   2   5   1     1     1     1     4     3     1     2     2     2
# 5    4   2   3   3     2     5     1     2     1     3     2     2     2
# 6    1   3   4   3     3     2     3     4     5     2     1     1     2
# 7    4   2   5   1     3     5     3     4     3     1     5     5     5
# 8    5   4   3   1     1     5     1     1     2     1     4     1     3
# 9    1   3   5   2     3     5     2     2     4     3     3     2     1
# 10   1   2   2   1     2     3     1     4     1     4     5     5     3
# 11   3   5   5   3     4     4     5     1     3     4     1     5     4
# 12   4   2   2   1     1     2     3     2     2     5     1     1     4
# 13   3   2   1   4     1     5     3     2     4     1     4     5     1
# 14   5   2   5   2     1     3     2     1     3     5     1     3     2
# 15   4   5   1   2     4     4     5     3     3     5     5     2     3
# 16   1   5   3   3     2     2     5     1     1     3     5     1     4
# 17   3   3   5   2     3     2     3     4     3     3     4     5     2
# 18   4   1   3   1     3     5     5     5     5     5     5     5     5
# 19   5   4   1   4     1     1     1     4     5     3     1     4     4
# 20   5   4   5   2     4     1     2     1     5     5     4     4     4
# 21   4   5   4   2     5     4     4     3     3     3     4     1     4
# 22   3   1   2   4     3     5     5     1     4     1     4     3     2
# 23   3   5   4   1     2     4     1     3     4     4     4     5     1
# 24   2   3   3   1     2     2     5     3     3     1     5     4     5
# 25   1   4   2   1     2     5     2     3     3     1     4     5     1
# 26   5   1   5   3     3     4     2     2     5     5     5     3     3
# 27   1   4   2   3     5     1     2     4     1     5     4     4     1
# 28   2   2   4   2     1     5     5     2     5     2     1     5     5
# 29   4   5   5   1     2     3     1     4     4     3     1     2     2
# 30   5   5   4   4     2     3     4     3     1     4     3     3     2
# 31   2   2   5   3     4     4     3     5     4     4     2     2     2
# 32   5   2   4   5     4     4     4     5     4     2     1     2     5
#
#     Q1.4  Q2.4  Q3.3  Average
# 0      3     5     2   2.9375
# 1      5     1     1   2.4375
# 2      1     1     5   3.1875
# 3      3     3     2   2.6875
# 4      4     4     3   2.5000
# 5      5     2     1   2.5000
# 6      2     3     3   2.6250
# 7      3     4     4   3.5625
# 8      2     5     5   2.7500
# 9      3     5     5   3.0625
# 10     4     4     1   2.6875
# 11     4     4     5   3.7500
# 12     3     4     1   2.3750
# 13     1     4     3   2.7500
# 14     2     3     2   2.6250
# 15     3     3     2   3.3750
# 16     3     3     3   2.8125
# 17     2     4     2   3.1250
# 18     3     1     2   3.6250
# 19     5     5     2   3.1250
# 20     4     3     3   3.5000
# 21     5     5     3   3.6875
# 22     2     3     2   2.8125
# 23     1     1     4   2.9375
# 24     3     3     2   2.9375
# 25     5     5     2   2.8750
# 26     5     2     2   3.4375
# 27     1     2     2   2.6250
# 28     2     2     3   3.0000
# 29     3     1     1   2.6250
# 30     3     3     5   3.3750
# 31     3     5     3   3.3125
# 32     3     4     5   3.6875

# %%
cor_matrix=df.corr()
cor_matrix
# Out:
#             Q1            Q2            Q3        Q4      Q1.1      Q2.1  \
# Q1    1.000000 -1.218581e-01  1.872559e-01  0.105650 -0.135090 -0.023610
# Q2   -0.121858  1.000000e+00  3.711770e-17 -0.152410  0.201259 -0.177942
# Q3    0.187256  3.711770e-17  1.000000e+00 -0.264406  0.170744 -0.021773
1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the correlation matrix
plt.figure(figsize=(22, 10))
sns.heatmap(cor_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df1=df.iloc[:,5:]
df1.head(5)
# Out:
#    Q2.1  Q1.2  Q2.2  Q3.1  Q4.1  Q1.3  Q2.3  Q3.2  Q1.4  Q2.4  Q3.3
# 0     2     1     4     3     2     3     4     1     3     5     2
# 1     3     1     5     2     1     1     2     2     5     1     1
# 2     4     2     3     4     3     5     5     5     1     1     5
# 3     3     1     3     4     5     3     4     1     3     3     2
# 4     1     1     4     3     1     2     2     2     4     4     3

# %%
import pandas as pd
fnames = ["Type of training (on the job, off the job etc)","Number of hours of training"," Content of Training","Skill Development","Knowledge Level in printing industry"]
f_dict = dict()

for i in range(0, 4):
    f_dict[fnames[i]] = df.iloc[:, 4 * i + 1:4 * i + 5].sum(axis=1)

fac_df = pd.DataFrame(f_dict)
print(fac_df.head())
# Out:
#    Type of training (on the job, off the job etc)  \
# 0                                              14
# 1                                              10
# 2                                              12
# 3                                               8
# 4                                               9
#
#    Number of hours of training   Content of Training  Skill Development
# 0                           10                    10                 10
# 1                           11                     6                  7
# 2                           13                    18                  7
# 3                           11                    13                  8
# 4                            9                     7                 11

# %%
fac_df['Score'] = fac_df.iloc[:, 0:4].sum(axis=1)
mean_score = fac_df['Score'].mean()
import numpy as np
fac_df['Satisfaction'] = np.where(fac_df['Score'] >= mean_score, 'High', 'Low')
fac_df.head(10)
# Out:
#    Type of training (on the job, off the job etc)  \
# 0                                              14
# 1                                              10
# 2                                              12
# 3                                               8
# 4                                               9
# 5                                              10
# 6                                              13
# 7                                              11
# 8                                               9
# 9                                              13
#
#    Number of hours of training   Content of Training  Skill Development  \
# 0                           10                    10                 10
# 1                           11                     6                  7
# 2                           13                    18                  7
# 3                           11                    13                  8
# 4                            9                     7                 11
# 5                            9                     9                  8
# 6                           14                     6                  8
# 7                           15                    16                 11
# 8                            9                     9                 12
# 9                           13                     9                 13
#
#    Score Satisfaction
# 0     44          Low
# 1     34          Low
# 2     50         High
# 3     40          Low
# 4     36          Low
# 5     36          Low
# 6     41          Low
# 7     53         High
# 8     39          Low
# 9     48         High

# %%
count=fac_df['Satisfaction'].value_counts()
count
# Out:
# Satisfaction
# High    17
# Low     16
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your DataFrame fac_data

# Calculate the correlation matrix
cor = fac_df.iloc[:, 0:4].corr()

# Create a clustered heatmap without using seaborn's clustermap
plt.figure(figsize=(8, 6))
sns.heatmap(cor, cmap='coolwarm', annot=True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Set the title
plt.title("Clustered Correlation Matrix Heatmap")

# Display the heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster import hierarchy
from sklearn.preprocessing import StandardScaler

linkage_matrix = hierarchy.linkage(cor, method='ward')

# Create a dendrogram
dendrogram = hierarchy.dendrogram(linkage_matrix, labels=cor.columns, orientation='top')
plt.xticks(rotation=90)
plt.title("Dendrogram of Correlation Matrix")
plt.show()
