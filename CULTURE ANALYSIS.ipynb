# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\SuryaKrishna\Desktop\HR LAB-5th SEM\Culture Analysis.xlsx",header=0)
df.head()
# Out:
#              NAME  AGE  GENDER  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q23  Q24  \
# 0  KrishnaPriya S    1       1   1   1   1   1   1   1    3  ...    2    3
# 1           Surya    2       2   1   5   4   2   1   2    2  ...    1    2
# 2         Praveen    4       2   4   3   1   3   2   1    1  ...    3    3
# 3     Khaleefulla    3       2   1   1   3   1   1   4    1  ...    3    3
# 4         Deepika    1       1   1   2   3   4   2   1    4  ...    3    2
#
#    Q25  Q26  Q27  Q28  Q29  Q30  Q31  Q32
# 0    1    1    1    1    1    2    1    1
# 1    2    2    2    2    2    3    3    3
# 2    2    1    1    1    1    1    4    2
# 3    3    3    3    3    2    1    3    1
# 4    2    2    1    2    1    2    4    2
#
# [5 rows x 32 columns]

# %%
df.drop_duplicates()
# Out:
#                NAME  AGE  GENDER  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q23  Q24  \
# 0    KrishnaPriya S    1       1   1   1   1   1   1   1    3  ...    2    3
# 1             Surya    2       2   1   5   4   2   1   2    2  ...    1    2
# 2           Praveen    4       2   4   3   1   3   2   1    1  ...    3    3
# 3       Khaleefulla    3       2   1   1   3   1   1   4    1  ...    3    3
# 4           Deepika    1       1   1   2   3   4   2   1    4  ...    3    2
# 5          Likkitha    2       1   5   1   3   2   4   1    1  ...    1    3
# 6     SRIVARSHINI.G    2       1   2   2   2   4   2   2    2  ...    2    2
# 7             Abith    4       2   4   4   5   1   1   2    3  ...    2    2
# 8         Mathesh S    3       2   1   2   2   2   2   2    2  ...    2    2
# 9            monish    2       2   1   1   1   2   2   1    1  ...    1    1
# 10           Xtreme    4       2   3   3   3   3   3   3    3  ...    3    3
# 11          Rithish    3       2   1   1   1   1   1   5    5  ...    1    1
# 12          Deepika    1       1   1   2   3   4   2   1    4  ...    3    2
# 13    SRIVARSHINI.G    2       1   2   2   2   4   2   2    2  ...    2    2
# 15   KrishnaPriya S    1       1   1   1   1   1   1   1    3  ...    2    3
# 16      Khaleefulla    2       2   1   5   4   2   1   2    2  ...    1    2
# 17            surya    4       2   4   3   1   3   2   1    1  ...    3    3
# 18          Praveen    3       2   1   1   3   1   1   4    1  ...    3    3
# 120         Praveen    3       2   1   1   3   1   1   4    1  ...    3    3
#
#      Q25  Q26  Q27  Q28  Q29  Q30  Q31  Q32
# 0      1    1    1    1    1    2    1    1
# 1      2    2    2    2    2    3    3    3
# 2      2    1    1    1    1    1    4    2
# 3      3    3    3    3    2    1    3    1
# 4      2    2    1    2    1    2    4    2
# 5      2    3    3    3    3    3    5    4
# 6      2    2    2    2    2    5    1    3
# 7      2    2    2    2    2    2    2    2
# 8      2    2    3    2    2    2    5    2
# 9      1    1    1    1    1    2    2    2
# 10     3    3    3    3    3    1    4    2
# 11     2    1    1    1    3    3    3    3
# 12     2    2    1    2    1    5    4    3
# 13     2    2    2    2    2    3    5    4
# 15     1    1    1    1    1    2    5    2
# 16     2    2    2    2    2    3    3    3
# 17     2    1    1    1    1    1    4    2
# 18     3    3    3    3    2    1    3    1
# 120    3    3    3    3    2    2    5    2
#
# [19 rows x 32 columns]

# %%
df.dtypes
# Out:
# NAME      object
# AGE        int64
# GENDER     int64
# Q4         int64
# Q5         int64
# Q6         int64
# Q7         int64
# Q8         int64
# Q9         int64
# Q10        int64
# Q11        int64
# Q12        int64
# Q13        int64
# Q14        int64
# Q15        int64
# Q16        int64
# Q17        int64
# Q18        int64
# Q19        int64
# Q20        int64
# Q21        int64
# Q22        int64
# Q23        int64
# Q24        int64
# Q25        int64
# Q26        int64
# Q27        int64
# Q28        int64
# Q29        int64
# Q30        int64
# Q31        int64
# Q32        int64
# dtype: object

# %%
null_values=df.isnull()
null_counts = null_values.sum()
print(null_counts)
# Out:
# NAME      0
# AGE       0
# GENDER    0
# Q4        0
# Q5        0
# Q6        0
# Q7        0
# Q8        0
# Q9        0
# Q10       0
# Q11       0
# Q12       0
# Q13       0
# Q14       0
# Q15       0
# Q16       0
# Q17       0
# Q18       0
# Q19       0
# Q20       0
# Q21       0
# Q22       0
# Q23       0
# Q24       0
# Q25       0
# Q26       0
# Q27       0
# Q28       0
# Q29       0
# Q30       0
# Q31       0
# Q32       0
# dtype: int64

# %%
df2_subset=df.iloc[:,0:]
print(df2_subset)
# Out:
#      Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13  ...  Q23  Q24  Q25  Q26  Q27  \
# 0     1   1   1   1   1   1    3    2    3    3  ...    2    3    1    1    1
# 1     1   5   4   2   1   2    2    2    1    4  ...    1    2    2    2    2
# 2     4   3   1   3   2   1    1    1    1    3  ...    3    3    2    1    1
# 3     1   1   3   1   1   4    1    1    2    4  ...    3    3    3    3    3
# 4     1   2   3   4   2   1    4    1    3    5  ...    3    2    2    2    1
# ..   ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 145   2   2   2   4   2   2    2    2    2    2  ...    2    2    2    2    2
# 146   4   4   5   1   1   2    3    3    2    5  ...    2    2    2    2    2
# 147   1   1   1   1   1   1    3    2    3    3  ...    2    3    1    1    1
# 148   1   5   4   2   1   2    2    2    1    4  ...    1    2    2    2    2
# 149   4   3   1   3   2   1    1    1    1    3  ...    3    3    2    1    1
#
#      Q28  Q29  Q30  Q31  Q32
# 0      1    1    2    1    1
# 1      2    2    3    3    3
# 2      1    1    1    4    2
# 3      3    2    1    3    1
# 4      2    1    2    4    2
# ..   ...  ...  ...  ...  ...
# 145    2    2    3    5    4
# 146    2    2    2    2    2
# 147    1    1    2    5    2
# 148    2    2    3    3    3
# 149    1    1    1    4    2
#
# [150 rows x 29 columns]

# %%
selected_columns = df2_subset.iloc[:, 0:29] 
correlation_matrix = selected_columns.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 selected_columns = df2_subset.iloc[:, 0:29]
#       2 correlation_matrix = selected_columns.corr()
#
# NameError: name 'df2_subset' is not defined

# %%
print(selected_columns)

# %%
print(correlation_matrix)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df2_subset.head(5)
# Out:
#    Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13  Q14  Q15  ...  Q23  Q24  Q25  Q26  Q27  \
# 0   1   1   1   1    3    2    3    3    3    3  ...    2    3    1    1    1
# 1   4   2   1   2    2    2    1    4    2    2  ...    1    2    2    2    2
# 2   1   3   2   1    1    1    1    3    1    2  ...    3    3    2    1    1
# 3   3   1   1   4    1    1    2    4    2    3  ...    3    3    3    3    3
# 4   3   4   2   1    4    1    3    5    4    2  ...    3    2    2    2    1
#
#    Q28  Q29  Q30  Q31  Q32
# 0    1    1    2    1    1
# 1    2    2    3    3    3
# 2    1    1    1    4    2
# 3    3    2    1    3    1
# 4    2    1    2    4    2
#
# [5 rows x 27 columns]

# %%
import pandas as pd
dfnames = ['Working Conditions', 'Relationship with Colleagues', 'Job Satisfaction', 'Company Policy', 'Rewards and Awards', 'Workload and Support']
df_dict = dict()

for i in range(0, 6):
    df_dict[dfnames[i]] = df.iloc[:, 4 * i + 1:4 * i + 5].sum(axis=1)

df_data = pd.DataFrame(df_dict)
print(df_data.head())
# Out:
#    Working Conditions  Relationship with Colleagues  Job Satisfaction  \
# 0                   4                             4                11
# 1                  10                             9                 9
# 2                  13                             7                 6
# 3                   7                             9                 8
# 4                   5                            10                13
#
#    Company Policy  Rewards and Awards  Workload and Support
# 0               8                   5                     8
# 1               7                   7                     7
# 2               9                  10                    11
# 3               9                  12                    12
# 4              10                   8                    10

# %%
df_data['Score'] = df_data.iloc[:, 0:6].sum(axis=1)
mean_score = df_data['Score'].mean()
import numpy as np
df_data['Satisfaction'] = np.where(df_data['Score'] >= mean_score, 'High', 'Low')
df_data.head(10)
# Out:
#    Working Conditions  Relationship with Colleagues  Job Satisfaction  \
# 0                   4                             4                11
# 1                  10                             9                 9
# 2                  13                             7                 6
# 3                   7                             9                 8
# 4                   5                            10                13
# 5                   9                            10                11
# 6                   7                            10                 8
# 7                  14                             9                13
# 8                   8                             8                 8
# 9                   6                             6                 7
#
#    Company Policy  Rewards and Awards  Workload and Support  Score  \
# 0               8                   5                     8     40
# 1               7                   7                     7     49
# 2               9                  10                    11     56
# 3               9                  12                    12     57
# 4              10                   8                    10     56
# 5              17                  12                     7     66
# 6               8                   8                     8     49
# 7               8                  10                     8     62
# 8              10                   8                     9     51
# 9               6                   4                     4     33
#
#   Satisfaction
# 0          Low
# 1          Low
# 2         High
# 3         High
# 4         High
# 5         High
# 6          Low
# 7         High
# 8          Low
# 9          Low

# %%
count=df_data['Satisfaction'].value_counts()
count
# Out:
# High    90
# Low     60
# Name: Satisfaction, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
cor = df_data.iloc[:, 0:6].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(cor, cmap='coolwarm', annot=True)
plt.xticks(rotation=90)
plt.title("Clustered Correlation Matrix Heatmap")
plt.show()

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\suryakrishna\appdata\local\programs\python\python311\lib\site-packages (1.11.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\suryakrishna\appdata\local\programs\python\python311\lib\site-packages (from scipy) (1.24.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster import hierarchy
from sklearn.preprocessing import StandardScaler

linkage_matrix = hierarchy.linkage(cor, method='ward')

# Create a dendrogram
dendrogram = hierarchy.dendrogram(linkage_matrix, labels=cor.columns, orientation='top')
plt.xticks(rotation=90)
plt.title("Dendrogram of Correlation Matrix")
plt.show()

# %%
df_data=df[['NAME','AGE','GENDER']].join(df_data)
max_positions = df_data.groupby('Satisfaction').max()
max_positions
# Out:
#                 NAME  AGE  GENDER  Working Conditions  \
# Satisfaction
# High           surya    4       2                  14
# Low           monish    3       2                  10
#
#               Relationship with Colleagues  Job Satisfaction  Company Policy  \
# Satisfaction
# High                                    12                19              17
# Low                                     10                11              10
#
#               Rewards and Awards  Workload and Support  Score
# Satisfaction
# High                          12                    12     72
# Low                            8                     9     51
